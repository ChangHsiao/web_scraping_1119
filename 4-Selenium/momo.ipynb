# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import time
import re
# 建立 Service 物件，指定 chromedriver.exe 的路徑

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗 避免 rwd
options.add_argument("--incognito") # 無痕模式 
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.momoshop.com.tw/")

time.sleep(5)

# 清空搜尋欄並輸入商品名按搜尋

cancle_product = driver.find_element(By.CSS_SELECTOR, ".relative.flex-1 input").clear()
insert_product = driver.find_element(By.CSS_SELECTOR, ".relative.flex-1 input").send_keys("Python")
start_find = driver.find_element(By.CSS_SELECTOR, ".flex.h-full.items-center.overflow-hidden button").click()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import time
# 建立 Service 物件，指定 chromedriver.exe 的路徑

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗 避免 rwd
options.add_argument("--incognito") # 無痕模式 
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.momoshop.com.tw/")

time.sleep(5)

# %%
# 清空搜尋欄並輸入商品名按搜尋

cancle_product = driver.find_element(By.CSS_SELECTOR, ".relative.flex-1 input").clear()
insert_product = driver.find_element(By.CSS_SELECTOR, ".relative.flex-1 input").send_keys("衛生紙")
start_find = driver.find_element(By.CSS_SELECTOR, ".flex.h-full.items-center.overflow-hidden button").click()

# %%
# 取得 script 內的 json 格式元素

try:
    data_element = driver.find_element(By.CSS_SELECTOR, "script[type='application/ld+json']")
except Exception as e:
    print("查無此項商品")

data_string = driver.execute_script("return arguments[0].textContent;",data_element)

try:
    fixed_string = re.sub(r',\s*([\]}])', r'\1', data_string, flags=re.DOTALL)
    fixed_string = fixed_string.replace("'", '"')
except json.JSONDecodeError as e:
    print("json 無法轉譯失敗")

json_data_elements = json.loads(fixed_string)
# print(json_data_elements)
# print(type(json_data_elements))
# 成功獲得 dict


product_list = json_data_elements.get('mainEntity',{}).get("itemListElement", [])
print(product_list)
# 獲得商品list
# Out:
# [{'@type': 'Product', 'name': '超圖解 Python 程式設計––從入門、網頁應用、YOLO 到生成式 AI 實作', 'position': '1', 'image': 'https://img1.momoshop.com.tw/goodsimg/0014/541/234/14541234_OL.jpg?t=1760379122', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=14541234&Area=search&mdiv=403&oid=1_1&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '631', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 5.0, 'reviewCount': 3}}, {'@type': 'Product', 'name': '史上最強Python入門邁向頂尖高手–王者歸來 第4版（全彩印刷）', 'position': '2', 'image': 'https://img1.momoshop.com.tw/goodsimg/0014/274/758/14274758_OL.jpg?t=1753799881', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=14274758&Area=search&mdiv=403&oid=1_2&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '843', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 5.0, 'reviewCount': 5}}, {'@type': 'Product', 'name': 'Python - 最強入門ChatGPT助攻AI數據科學 - 王者歸來', 'position': '3', 'image': 'https://img1.momoshop.com.tw/goodsimg/0014/038/676/14038676_OL.jpg?t=1747839240', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=14038676&Area=search&mdiv=403&oid=1_3&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '843', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 5.0, 'reviewCount': 4}}, {'@type': 'Product', 'name': 'Python自學聖經（第三版）：從程式素人到開發強者的技術、實戰與AI應用大全（附影音/範例程式）', 'position': '4', 'image': 'https://img1.momoshop.com.tw/goodsimg/0013/338/238/13338238_OL.jpg?t=1728925082', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=13338238&Area=search&mdiv=403&oid=1_4&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '695', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 5.0, 'reviewCount': 5}}, {'@type': 'Product', 'name': 'Clean Code：Python 寫乾淨程式碼 - 告別技術債，不再為爛程式加班收爛攤', 'position': '5', 'image': 'https://img1.momoshop.com.tw/goodsimg/0014/479/199/14479199_OL.jpg?t=1758709322', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=14479199&Area=search&mdiv=403&oid=1_5&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '568', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 5.0, 'reviewCount': 2}}, {'@type': 'Product', 'name': '一步到位Python\u3000程式設計最強入門教科書\u3000第四版', 'position': '6', 'image': 'https://img1.momoshop.com.tw/goodsimg/0012/868/537/12868537_OL.jpg?t=1721925602', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=12868537&Area=search&mdiv=403&oid=1_6&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '497', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 4.9, 'reviewCount': 7}}, {'@type': 'Product', 'name': '史上最強Python入門邁向頂尖高手之路王者歸來 第3版（全彩印刷）', 'position': '7', 'image': 'https://img1.momoshop.com.tw/goodsimg/0012/199/843/12199843_OL.jpg?t=1702021705', 'description': '下單79折 滿額最高再享84折', 'url': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=12199843&Area=search&mdiv=403&oid=1_7&cid=index&kw=Python', 'offers': {'@type': 'Offer', 'price': '843', 'priceCurrency': 'TWD', 'availability': 'https://schema.org/InStock'}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 5.0, 'reviewCount': 10}}, {'@type': 'Product', 'name': '世界第一簡單的 Python「超」入門 - 零基礎 OK！ChatGPT 隨時當助教！', 'position': '8', 'image': 'https://img1.momoshop.com.tw/goodsimg/0011/615/070/11615070_OL.jpg?t=1692556389', 'descr ...

# %%
# 將我們需要的商品名稱、價格、圖片、購買連結取出
product_data = []
for item in product_list:
    if item.get('@type') == 'Product' and 'offers' in item:
        offers = item.get('offers', {})
        product_info = {
            "商品名": item.get('name', 'N/A'),
            "價格(新台幣)": offers.get('price', 'N/A'), 
            "圖片URL": item.get('image', 'N/A'),
            "購買連結": item.get('url', 'N/A')
        }
        product_data.append(product_info)
    else:
        print("商品資訊不全，不顯示")
# for p in product_data[:5]:
#     print(p)
print(product_data)
# Out:
# [{'商品名': '【MAY FLOWER 五月花】厚棒抽取式衛生紙(90抽x60包)', '價格': '1169', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0006/532/205/6532205_OL.jpg?t=1763085631', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=6532205&Area=search&mdiv=403&oid=1_1&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【YAMAZAKI】tower沉蓋式面紙盒-白(面紙盒/抽取式面紙盒/面紙盒/衛生紙盒)', '價格': '1145', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0009/656/372/9656372_OL.jpg?t=1693158374', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9656372&Area=search&mdiv=403&oid=1_2&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【Vinda 維達】線條小狗聯名款 掛式3層衛生紙 280抽*1包 尺寸14.6*19.5cm 加厚立體壓花 100%原生木漿 抽取衛生紙', '價格': '$89', '圖片URL': 'https://i8.momoshop.com.tw/1763185950/goodsimg/TP000/8488/0000/008/TP00084880000008_O_m.jpg', '購買連結': ' https://www.momoshop.com.tw/TP/TP0008488/goodsDetail/TP00084880000008'}, {'商品名': '【倍潔雅】花漾柔感抽取式衛生紙PEFC(150抽x84包/箱)', '價格': '979', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0008/037/995/8037995_OL.jpg?t=1763086527', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8037995&Area=search&mdiv=403&oid=1_3&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【櫻花】超值新柔感抽取式衛生紙(150抽x84包/箱)', '價格': '709', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0004/617/672/4617672_OL.jpg?t=1744420915', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4617672&Area=search&mdiv=403&oid=1_4&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【舒潔xmomo獨家】熱銷霸王抽取衛生紙110抽x60包/*2箱', '價格': '1510', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0010/228/197/10228197_OL.jpg?t=1763455937', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10228197&Area=search&mdiv=403&oid=1_5&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【倍潔雅】舒感柔韌抽取式衛生紙PEFC(150抽x70包/箱)', '價格': '719', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0010/116/136/10116136_OL.jpg?t=1762927240', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10116136&Area=search&mdiv=403&oid=1_6&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【朵舒】momoco舒適柔韌抽取式衛生紙(150抽x80包/箱)', '價格': '899', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0008/531/746/8531746_OL.jpg?t=1763030269', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8531746&Area=search&mdiv=403&oid=1_7&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【朵舒】棉仔紙超厚柔抽取式衛生紙(150抽x84包/箱)', '價格': '939', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0010/019/468/10019468_OL.jpg?t=1763030366', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10019468&Area=search&mdiv=403&oid=1_8&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【Kleenex 舒潔】絲絨舒膚抽取衛生紙110抽x60包/箱', '價格': '725', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0010/047/232/10047232_OL.jpg?t=1763006431', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=10047232&Area=search&mdiv=403&oid=1_9&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【Kirkland Signature 科克蘭】三層抽取式衛生紙(120抽x72包)', '價格': '1680', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0011/735/069/11735069_OL.jpg?t=1693377214', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11735069&Area=search&mdiv=403&oid=1_10&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【東京豪德寺xmomo獨家】招財貓日式抽取式衛生紙(150抽x100包/箱)', '價格': '1068', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0014/362/212/14362212_OL.jpg?t=1763086420', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=14362212&Area=search&mdiv=403&oid=1_11&cid=index&kw=%E8%A1%9B%E7%94%9F%E7%B4%99'}, {'商品名': '【Kirkland Signature 科克蘭】三層抽取衛生紙 120抽 X 72入 免運', '價格': '$1,335', '圖片URL': 'https://i5.momoshop.com.tw/1763348924/goodsimg/TP000/3703/0000/107/TP00037030000107_O.webp', '購買連結': ' https://www.momoshop.com.tw/TP/TP0003703/goodsDetail/TP00037030000107'}, {'商品名': '【Kirkland Signature 科克蘭】三層抽取式衛生紙(120抽x24包)', '價格': '599', '圖片URL': 'https://img4.momoshop.com.tw/goodsimg/0011/773/369/11773369_OL.jpg?t=1755666127', '購買連結': 'https://ww ...

# %%
# 找下一頁按鈕,並點案持續搜尋

page_number = 1

while True:
    next_page_btn= driver.find_elements(By.CSS_SELECTOR, ".page-btn.page-next")
    if next_page_btn:
        next_page_btn = next_page_btn[0]
        next_page_btn.click()
        time.sleep(3)
        page_number += 1
    else:
        break

# %%
# 進入商品列
product_elements = driver.find_elements(By.CSS_SELECTOR, ".listAreaUl li")
print(f"找到{len(product_elements)}個商品")
# product_data_list = []
# for product in product_elements:
#     product_name = product.find_element(By.CSS_SELECTOR, ".listAreaLi .goodsUrl .prdNameTitle").text
#     product_price = product.find_element(By.CSS_SELECTOR, ".listAreaLi .goodsUrl .prdInfoWrap .money").text
#     product_image = product.find_element(By.CSS_SELECTOR, ".listAreaLi .goodsUrl .prdImgWrap .swiper .swiper-wrapper .swiper-slide .goods-img-url picture img").get_attribute("src")
#     # print(product_image)
#     data_element = driver.find_element(By.CSS_SELECTOR, "script[type='application/ld+json']")
#     data_string = driver.execute_script("return arguments[0].textContent;",data_element)
#     clean_string = data_string.strip()
#     url_pattern = re.compile(r'"url"\s*:\s*"(.*?)"', re.DOTALL)
#     all_urls = url_pattern.findall(clean_string)

#     # product_data_list.append({
#     #     print(f"名稱: {product_name}")
#     #     print (f"")
#     #     print (f"")
#     # })
#     break
# Out:
# 找到30個商品
