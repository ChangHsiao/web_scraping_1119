# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import time
import re
# 建立 Service 物件，指定 chromedriver.exe 的路徑

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗 避免 rwd
options.add_argument("--incognito") # 無痕模式 
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.momoshop.com.tw/")

time.sleep(5)

# 清空搜尋欄並輸入商品名按搜尋

cancle_product = driver.find_element(By.CSS_SELECTOR, ".relative.flex-1 input").clear()
insert_product = driver.find_element(By.CSS_SELECTOR, ".relative.flex-1 input").send_keys("javar script")
start_find = driver.find_element(By.CSS_SELECTOR, ".flex.h-full.items-center.overflow-hidden button").click()

# %%
# 將我們需要的商品名稱、價格、圖片、購買連結取出
all_product = []
page_number = 1

while True:

    if page_number >= 1:
        time.sleep(3)

    try:
        data_element = driver.find_element(By.CSS_SELECTOR, "script[type='application/ld+json']")
    except Exception as e:
        print("查無此項商品")

    data_string = driver.execute_script("return arguments[0].textContent;",data_element)

    try:
        fixed_string = re.sub(r',\s*([\]}])', r'\1', data_string, flags=re.DOTALL)
        fixed_string = fixed_string.replace("'", '"')
        json_data_elements = json.loads(fixed_string)
    except json.JSONDecodeError as e:
        print("json 無法轉譯失敗")

    

    product_list = json_data_elements.get('mainEntity',{}).get("itemListElement", [])

    for item in product_list:
        if item.get('@type') == 'Product' and 'offers' in item:
            offers = item.get('offers', {})
            product_info = {
                "商品名": item.get('name', 'N/A'),
                "價格(新台幣)": offers.get('price', 'N/A'), 
                "圖片URL": item.get('image', 'N/A'),
                "購買連結": item.get('url', 'N/A')
            }
            all_product.append(product_info)
        else:
            print("查無此商品")
    next_page_btn= driver.find_elements(By.CSS_SELECTOR, ".page-btn.page-next")
    if next_page_btn:
        next_page_btn = next_page_btn[1]
        next_page_btn.click()
        time.sleep(5)
        page_number += 1
    else:
        break
print(all_product)
# Out:
# json 無法轉譯失敗
# [{'商品名': '圖解資料結構－使用Python（第二版）', '價格(新台幣)': '395', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/711/730/8711730_OL.jpg?t=1692997929', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8711730&Area=search&mdiv=403&oid=10_1&cid=index&kw=Python'}, {'商品名': '類神經網路實戰：使用Python', '價格(新台幣)': '331', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/711/124/8711124_OL.jpg?t=1692998000', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8711124&Area=search&mdiv=403&oid=10_2&cid=index&kw=Python'}, {'商品名': '軟硬通吃學Python程式設計與Halocode光環板創客應用', '價格(新台幣)': '379', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/613/019/8613019_OL.jpg?t=1692989779', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8613019&Area=search&mdiv=403&oid=10_3&cid=index&kw=Python'}, {'商品名': '資訊社會必修的12堂Python通識課', '價格(新台幣)': '410', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/711/727/8711727_OL.jpg?t=1692997917', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8711727&Area=search&mdiv=403&oid=10_4&cid=index&kw=Python'}, {'商品名': '簡潔的Python｜重構你的舊程式', '價格(新台幣)': '379', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/557/488/8557488_OL.jpg?t=1692984360', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8557488&Area=search&mdiv=403&oid=10_5&cid=index&kw=Python'}, {'商品名': 'Python不廢話 一行程式碼︱像高手般寫出簡潔有力的Python程式碼', '價格(新台幣)': '355', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0009/454/017/9454017_OL.jpg?t=1693007048', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9454017&Area=search&mdiv=403&oid=10_6&cid=index&kw=Python'}, {'商品名': 'Python程式設計實例入門', '價格(新台幣)': '284', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0009/451/824/9451824_OL.jpg?t=1693006626', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9451824&Area=search&mdiv=403&oid=10_7&cid=index&kw=Python'}, {'商品名': '秋聲教你玩Python：給挑戰者的修行之路', '價格(新台幣)': '355', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/678/734/8678734_OL.jpg?t=1692995450', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8678734&Area=search&mdiv=403&oid=10_8&cid=index&kw=Python'}, {'商品名': 'Python基礎必修課－第二版（含MTA Python微軟國際認證模擬試題）', '價格(新台幣)': '355', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0009/646/420/9646420_OL.jpg?t=1693157521', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=9646420&Area=search&mdiv=403&oid=10_9&cid=index&kw=Python'}, {'商品名': 'Python程式設計入門與應用：運算思維的提昇與修練', '價格(新台幣)': '408', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0011/346/556/11346556_OL.jpg?t=1692464715', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11346556&Area=search&mdiv=403&oid=10_10&cid=index&kw=Python'}, {'商品名': '進階程式設計-使用Python、C++', '價格(新台幣)': '276', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/554/687/8554687_OL.jpg?t=1692983959', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8554687&Area=search&mdiv=403&oid=10_11&cid=index&kw=Python'}, {'商品名': 'Python 3.7 技術手冊', '價格(新台幣)': '442', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/561/397/8561397_OL.jpg?t=1692984789', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8561397&Area=search&mdiv=403&oid=10_12&cid=index&kw=Python'}, {'商品名': 'Python X ChatGPT+Python實戰聖經', '價格(新台幣)': '802', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0011/431/030/11431030_OL.jpg?t=1692474554', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=11431030&Area=search&mdiv=403&oid=10_13&cid=index&kw=Python'}, {'商品名': 'Effective Python 中文版 ： 寫出良好 Python 程式的 59 個具體做法', '價格(新台幣)': '355', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/599/227/8599227_L.jpg?t=1614980940', '購買連結': 'https://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=8599227&Area=search&mdiv=403&oid=10_14&cid=index&kw=Python'}, {'商品名': '用Python學程式設計運算思維（收錄MTA Python微軟國際認證模擬試題）', '價格(新台幣)': '331', '圖片URL': 'https://img2.momoshop.com.tw/goodsimg/0008/576/545/8576545_OL.jpg?t=1692986352', '購買連結': 'htt ...

# %%
# 找下一頁按鈕,並點案持續搜尋

page_number = 1

while True:
    next_page_btn= driver.find_elements(By.CSS_SELECTOR, ".page-btn.page-next")
    if next_page_btn:
        next_page_btn = next_page_btn[0]
        next_page_btn.click()
        time.sleep(3)
        page_number += 1
    else:
        break

# %%
# 進入商品列
product_elements = driver.find_elements(By.CSS_SELECTOR, ".listAreaUl li")
# print(f"找到{len(product_elements)}個商品")
product_data_list = []
for product in product_elements:
    product_name = product.find_element(By.CSS_SELECTOR, ".listAreaLi .goodsUrl .prdNameTitle").text
    product_price = product.find_element(By.CSS_SELECTOR, ".listAreaLi .goodsUrl .prdInfoWrap .money").text
    product_image = product.find_element(By.CSS_SELECTOR, ".listAreaLi .goodsUrl .prdImgWrap .swiper .swiper-wrapper .swiper-slide .goods-img-url picture img").get_attribute("src")
    # print(product_image)
    product_link = product.find_element(By.TAG_NAME, "a").get_attribute("href")
    print(product_link)

    # product_data_list.append({
    #     print(f"名稱: {product_name}")
    #     print (f"")
    #     print (f"")
    # })
    break
# Out:
# None
